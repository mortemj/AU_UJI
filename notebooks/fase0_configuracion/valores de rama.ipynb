# %%
import pandas as pd
from pathlib import Path

meta = pd.read_parquet(
    r"C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\06_evaluacion\meta_test.parquet"
)
print(meta["rama"].dtype)
print(meta["rama"].unique())
# Out:
# object
# ['SO' 'SA' 'TE' 'HU' 'EX']
