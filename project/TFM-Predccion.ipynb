# %% [markdown]
# README TÉCNICO DEL PROYECTO

# %% [markdown]
# # 📘 TFM – Predicción de Abandono Universitario
# ### Arquitectura técnica del proyecto
#
# Este proyecto implementa un pipeline modular para la limpieza, integración, análisis y modelado de datos académicos con el objetivo de predecir el abandono universitario.
#
# ---

# %% [markdown]
# ## 🧱 Estructura del proyecto
#
# project/
# │
# ├── src/
# │   ├── config/
# │   │   ├── config.py
# │   │   ├── config_entorno.py
# │   │   ├── config_datos.py
# │   │   ├── config_utils.py
# │   │   └── constants.py
# │   │
# │   ├── utils/
# │   │   ├── log.py
# │   │   ├── io.py
# │   │   └── helpers.py
# │   │
# │   ├── features/
# │   ├── models/
# │   ├── eda/
# │   └── pipelines/
# │
# ├── data/
# │   ├── 01_raw/
# │   ├── 02_interim/
# │   └── 03_processed/
# │
# ├── docs/
# │   ├── html/
# │   ├── eda/
# │   ├── reportes/
# │   └── assets/
# │
# ├── notebooks/
# ├── logs/
# └── tests/
#
# ---
#
# ## ⚙️ Configuración central
#
# Toda la configuración se gestiona desde:
#
# `src/config/`
#
# ### ✅ `config_entorno.py`
# Detecta el entorno (Local, Colab, Kaggle, Azure) y define rutas del proyecto.
#
# ### ✅ `config_datos.py`
# Reexporta diccionarios y constantes desde `constants.py`.
#
# ### ✅ `config_utils.py`
# Funciones de diagnóstico, verificación de directorios y resúmenes.
#
# ### ✅ `constants.py`
# Diccionarios de metadatos, valores nulos, códigos, ramas, formas de pago, etc.
#
# ---
#
# ## 📝 Logging
#
# El proyecto usa un logger homogéneo definido en:
#
# `src/utils/log.py`
#
# Niveles disponibles:
# `log_info`, `log_warning`, `log_error`, `log_debug`, `log_success`.
#
# ---
#
# ## ▶️ Ejecución del diagnóstico
#
# ```python
# from src.config import diagnostico_proyecto
# diagnostico_proyecto()

# %%
# 📘 TFM – Predicción de Abandono Universitario  
### Arquitectura técnica del proyecto

Este proyecto implementa un pipeline modular para la limpieza, integración, análisis y modelado de datos académicos con el objetivo de predecir el abandono universitario.

---

## 🧱 Estructura del proyecto

project/
│
├── src/
│   ├── config/
│   │   ├── config.py
│   │   ├── config_entorno.py
│   │   ├── config_datos.py
│   │   ├── config_utils.py
│   │   └── constants.py
│   │
│   ├── utils/
│   │   ├── log.py
│   │   ├── io.py
│   │   └── helpers.py
│   │
│   ├── features/
│   ├── models/
│   ├── eda/
│   └── pipelines/
│
├── data/
│   ├── 01_raw/
│   ├── 02_interim/
│   └── 03_processed/
│
├── docs/
│   ├── html/
│   ├── eda/
│   ├── reportes/
│   └── assets/
│
├── notebooks/
├── logs/
└── tests/

---

## ⚙️ Configuración central

Toda la configuración se gestiona desde:

`src/config/`

### ✅ `config_entorno.py`  
Detecta el entorno (Local, Colab, Kaggle, Azure) y define rutas del proyecto.

### ✅ `config_datos.py`  
Reexporta diccionarios y constantes desde `constants.py`.

### ✅ `config_utils.py`  
Funciones de diagnóstico, verificación de directorios y resúmenes.

### ✅ `constants.py`  
Diccionarios de metadatos, valores nulos, códigos, ramas, formas de pago, etc.

---

## 📝 Logging

El proyecto usa un logger homogéneo definido en:

`src/utils/log.py`

Niveles disponibles:  
`log_info`, `log_warning`, `log_error`, `log_debug`, `log_success`.

---

## ▶️ Ejecución del diagnóstico

```python
from src.config import diagnostico_proyecto
diagnostico_proyecto()

# %% [markdown]
# ✨ Autoría
# María José Morte TFM – Predicción de Abandono Universitario Universitat Oberta de Catalunya

# %%
---

# ✅ **CELDA 2 — MAPA VISUAL DE DEPENDENCIAS**  
**¿Qué es?**  
Un diagrama que muestra cómo se relacionan tus módulos.  
Sirve para entender la arquitectura de un vistazo.

**Copia y pega esto tal cual:**

---

### ✅ **CELDA 2 — MAPA VISUAL**

```markdown
# 🗺️ Mapa visual de dependencias

CONFIGURACIÓN
│
├── config.py
│     ├── config_entorno.py
│     ├── config_datos.py
│     ├── config_utils.py
│     └── constants.py
│
├── config_entorno.py
│     ├── detectar_entorno()
│     ├── BASE_PATH, ENTORNO
│     └── rutas del proyecto
│
├── config_utils.py
│     ├── info_entorno()
│     ├── verificar_directorios()
│     ├── resumen_tablas()
│     ├── resumen_columnas()
│     └── diagnostico_proyecto()
│
└── config_datos.py
      └── constants.py

---

## 🔄 Flujo general del proyecto

RAW → INTERIM → PROCESSED → FEATURES → MODELOS → REPORTES

---

## 🔗 Dependencias principales

constants.py → config_datos.py → config.py → resto del proyecto  
config_entorno.py → config_utils.py → diagnostico_proyecto()  
log.py → todo el proyecto

# %% [markdown]
# CELDA 3 — CHECKLIST FINAL DE LIMPIEZA

# %%
# ✅ Checklist final de limpieza

## ✅ Configuración
- [x] `config_entorno.py` solo contiene entorno y rutas  
- [x] `config_utils.py` solo contiene diagnóstico y utilidades  
- [x] `config_datos.py` solo reexporta constantes  
- [x] `constants.py` contiene todos los diccionarios  
- [x] No hay `import *`  
- [x] No hay `print()` en ningún módulo  
- [x] Todo usa `log_info`, `log_success`, etc.

## ✅ Logging
- [x] Logger unificado  
- [x] Formato homogéneo  
- [x] Sin prints en ningún módulo

## ✅ Rutas
- [x] Todas las rutas se derivan de `BASE_PATH`  
- [x] No hay rutas hardcodeadas en ningún módulo

## ✅ Diccionarios
- [x] Sin duplicados  
- [x] `DICCIONARIO_CP_PROVINCIA` solo en `constants.py`  
- [x] `VALORES_NULOS` y `VALORES_VACIOS` bien definidos

## ✅ Diagnóstico
- [x] `diagnostico_proyecto()` funciona  
- [x] `info_entorno()` movida correctamente  
- [x] `verificar_directorios()` crea todas las carpetas

## ✅ Preparado para F1_M00
- [x] Arquitectura estable  
- [x] Configuración limpia  
- [x] Dependencias claras  
- [x] Logging listo  
- [x] Diccionarios listos  
- [x] Rutas listas
