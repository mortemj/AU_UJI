# %%
import pandas as pd
from pathlib import Path

# Ver estructura de df_exp_automl_target
ruta_feat = Path(r'C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\03_features')
df_exp = pd.read_parquet(ruta_feat / 'df_exp_automl_target.parquet')
print(f"Shape: {df_exp.shape}")
print(f"Index: {df_exp.index[:5].tolist()}")
print(f"per_id_ficticio primeros 5: {df_exp['per_id_ficticio'].head().tolist()}")

# Ver curso_aca_ini, vive_fuera, cupo en df_alumno_limpio
df_lim = pd.read_parquet(ruta_feat / 'df_alumno_limpio.parquet')
print(f"\ndf_alumno_limpio shape: {df_lim.shape}")
print(f"Index: {df_lim.index[:5].tolist()}")
cols = ['per_id_ficticio', 'curso_aca_ini', 'vive_fuera', 'cupo']
print(f"\nPrimeras 5 filas cols útiles:")
print(df_lim[cols].head())
print(f"\nvive_fuera valores únicos: {df_lim['vive_fuera'].unique().tolist()}")
print(f"cupo valores: {df_lim['cupo'].value_counts().head(8).to_dict()}")
# Out:
# Shape: (33621, 46)
# Index: [0, 1, 2, 3, 4]
# per_id_ficticio primeros 5: [106, 134, 426, 470, 516]
#
# df_alumno_limpio shape: (109568, 42)
# Index: [0, 1, 2, 3, 4]
#
# Primeras 5 filas cols útiles:
#    per_id_ficticio  curso_aca_ini  vive_fuera     cupo
# 0              106           2012        True  General
# 1              134           2009       False     None
# 2              134           2009       False     None
# 3              134           2009       False     None
# 4              426           2010       False  General
#
# vive_fuera valores únicos: [True, False]
# cupo valores: {'General': 92500, 'Mayor 25 Años': 1970, 'Titulados': 815, 'Mayor 40años': 96, 'Minusvalidos': 85, 'Mayor 45años': 80, 'Deportistas Alto Nivel': 75, 'Mayor 40 Años': 66}
