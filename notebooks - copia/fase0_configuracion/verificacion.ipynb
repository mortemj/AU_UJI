# %%
==================================================
VERIFICACIÓN DE IMPORTS
==================================================

📁 RUTA_RAW:       C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\00_raw
📁 RUTA_INTERIM:   C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\01_interim
📁 RUTA_PROCESSED: C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\02_processed
📁 RUTA_FEATURES:  C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\03_features
📁 RUTA_AUTOML:    C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\automl

👩 AUTORA:      María José Morte
📧 EMAIL_UOC:   mjmorteruiz@uoc.edu
📧 EMAIL_UJI:   morte@uji.es
🔗 GITHUB:      https://github.com/mortemj/AU_UJI
🎨 COLOR:       #3182ce

📊 Tablas definidas:    9
📊 Valores vacíos:     13
📊 Fases configuradas: 7

✅ TODO CORRECTO — Reorganización completada

# %%
# === VERIFICACIÓN DE REORGANIZACIÓN ===
from src.config import RUTA_RAW, RUTA_INTERIM, RUTA_PROCESSED, RUTA_FEATURES, RUTA_AUTOML
from src.config import AUTORA, EMAIL_UOC, EMAIL_UJI
from src.config import GITHUB_REPO, COLORES, FASES_CONFIG
from src.config import TABLAS_INFO, VALORES_VACIOS

print("=" * 50)
print("VERIFICACIÓN DE IMPORTS")
print("=" * 50)
print(f"\n📁 RUTA_RAW:       {RUTA_RAW}")
print(f"📁 RUTA_INTERIM:   {RUTA_INTERIM}")
print(f"📁 RUTA_PROCESSED: {RUTA_PROCESSED}")
print(f"📁 RUTA_FEATURES:  {RUTA_FEATURES}")
print(f"📁 RUTA_AUTOML:    {RUTA_AUTOML}")
print(f"\n👩 AUTORA:      {AUTORA}")
print(f"📧 EMAIL_UOC:   {EMAIL_UOC}")
print(f"📧 EMAIL_UJI:   {EMAIL_UJI}")
print(f"🔗 GITHUB:      {GITHUB_REPO}")
print(f"🎨 COLOR:       {COLORES.PRINCIPAL}")
print(f"\n📊 Tablas definidas:    {len(TABLAS_INFO)}")
print(f"📊 Valores vacíos:     {len(VALORES_VACIOS)}")
print(f"📊 Fases configuradas: {len(FASES_CONFIG)}")

errores = []
for nombre, ruta in [('RAW', RUTA_RAW), ('INTERIM', RUTA_INTERIM), ('PROCESSED', RUTA_PROCESSED)]:
    ruta_str = str(ruta)
    if '01_raw' in ruta_str or '02_interim' in ruta_str or '03_processed' in ruta_str:
        errores.append(f"⚠️ {nombre} tiene ruta ANTIGUA: {ruta}")
    if 'TFM_AU' in ruta_str or 'TFM_abandono' in ruta_str:
        errores.append(f"⚠️ {nombre} tiene nombre ANTIGUO: {ruta}")

if errores:
    print("\n❌ ERRORES:")
    for e in errores:
        print(f"  {e}")
else:
    print("\n✅ TODO CORRECTO — Reorganización completada")
