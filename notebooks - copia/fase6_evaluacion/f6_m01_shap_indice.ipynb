# %% [markdown]
# # f6_m01_shap_indice.ipynb
# **TFM: Pronóstico del Éxito y del Abandono en los Títulos de Grado de la UJI**
#
# | | |
# |---|---|
# | **Autora** | María José Morte Ruiz |
# | **Institución** | UOC + Universitat Jaume I |
# | **Email** | mjmorteruiz@uoc.edu · morte@uji.es |
# | **Fase** | 6 — Interpretabilidad y Evaluación Final |
# | **Módulo** | M01 — SHAP (Índice) |
#
# ---
#
# ## 🎯 Qué hace
#
# Página índice del grupo SHAP. Muestra los 4 submódulos con descripción y enlace directo.
#
# ## 📋 Requisitos
#
# - `src/html/render.py` con `render_pagina_desde_fichero()`
#
# ## 📤 Genera
#
# | Archivo | Contenido |
# |---|---|
# | `docs/html/fase6/m01_interpretabilidad_shap.html` | Índice del grupo con enlaces a submódulos |
#
# ## 🔄 Flujo
#
# ```
# render_pagina_desde_fichero() → HTML índice de grupo → escribe en disco
# ```
#
# ## ➡️ Siguiente
#
# Ejecutar los submódulos del grupo.

# %%
# 1. CONFIG
import sys
from pathlib import Path

ROOT = Path.cwd()
for _ in range(6):
    if (ROOT / 'src').exists():
        break
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
print(f'ROOT: {ROOT}')
# Out:
# ROOT: C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI

# %%
# 2. GENERAR HTML ÍNDICE DE GRUPO
from src.html.render import render_pagina_desde_fichero

contenido = '''<h2 style="color:#2d3748;margin-bottom:8px">M01 — SHAP (Índice)</h2><p style="color:#4a5568;font-size:14px;max-width:800px;margin-bottom:24px">Página índice del grupo SHAP. Muestra los 4 submódulos con descripción y enlace directo.</p><table style="width:100%;border-collapse:collapse;font-size:13px"><thead><tr style="background:#edf2f7"><th style="padding:10px 14px;width:50px"></th><th style="padding:10px 14px;text-align:left">Submódulo</th><th style="padding:10px 14px;width:80px"></th></tr></thead><tbody><tr style="cursor:pointer" onclick="window.location='m01a_shap_global.html'">
  <td style="padding:12px 14px;font-size:20px;text-align:center">🌍</td>
  <td style="padding:12px 14px">
    <a href="m01a_shap_global.html" style="font-weight:600;color:#2d3748;text-decoration:none">SHAP Global</a>
    <div style="font-size:12px;color:#718096;margin-top:3px">Importancia global de features: beeswarm, bar plot y heatmap sobre CatBoost, EBM y RF.</div>
  </td>
  <td style="padding:12px 14px;text-align:right;color:#3182ce;font-size:13px">Ver →</td>
</tr>
<tr style="cursor:pointer" onclick="window.location='m01b_shap_local.html'">
  <td style="padding:12px 14px;font-size:20px;text-align:center">🔬</td>
  <td style="padding:12px 14px">
    <a href="m01b_shap_local.html" style="font-weight:600;color:#2d3748;text-decoration:none">SHAP Local</a>
    <div style="font-size:12px;color:#718096;margin-top:3px">Explicaciones individuales: waterfall, force plot y decision plot por alumno.</div>
  </td>
  <td style="padding:12px 14px;text-align:right;color:#3182ce;font-size:13px">Ver →</td>
</tr>
<tr style="cursor:pointer" onclick="window.location='m01c_shap_cohortes.html'">
  <td style="padding:12px 14px;font-size:20px;text-align:center">👥</td>
  <td style="padding:12px 14px">
    <a href="m01c_shap_cohortes.html" style="font-weight:600;color:#2d3748;text-decoration:none">SHAP Cohortes</a>
    <div style="font-size:12px;color:#718096;margin-top:3px">SHAP segmentado por titulación, rama y tipo de acceso.</div>
  </td>
  <td style="padding:12px 14px;text-align:right;color:#3182ce;font-size:13px">Ver →</td>
</tr>
<tr style="cursor:pointer" onclick="window.location='m01d_shapash.html'">
  <td style="padding:12px 14px;font-size:20px;text-align:center">📊</td>
  <td style="padding:12px 14px">
    <a href="m01d_shapash.html" style="font-weight:600;color:#2d3748;text-decoration:none">Shapash</a>
    <div style="font-size:12px;color:#718096;margin-top:3px">Dashboard interactivo Plotly con waterfall, beeswarm filtrable y tabla de alumnos.</div>
  </td>
  <td style="padding:12px 14px;text-align:right;color:#3182ce;font-size:13px">Ver →</td>
</tr>
</tbody></table>'''

html_completo = render_pagina_desde_fichero('f6_m01_shap_indice.ipynb', contenido)
ruta_html = ROOT / 'docs' / 'html' / 'fase6' / 'm01_interpretabilidad_shap.html'
ruta_html.parent.mkdir(parents=True, exist_ok=True)
ruta_html.write_text(html_completo, encoding='utf-8')
print(f'✅ HTML generado: {ruta_html}')
# Out:
# ✅ HTML generado: C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\docs\html\fase6\m01_interpretabilidad_shap.html
