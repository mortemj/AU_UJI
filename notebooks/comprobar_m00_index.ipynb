# %%
from pathlib import Path

ROOT = Path(r'C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI')

htmls = [
    'fase1/fase1_index.html',
    'fase2/fase2_index.html', 
    'fase3/fase3_index.html',
    'fase1/m00_ejecucion.html',
    'fase2/m00_ejecucion.html',
    'fase3/m00_ejecucion.html',
]

for h in htmls:
    ruta = ROOT / 'docs' / 'html' / h
    ok = ruta.exists()
    mb = f'{ruta.stat().st_size/1024:.0f} KB' if ok else '—'
    print(f'{"✅" if ok else "❌"} {h}: {mb}')
# Out:
# ✅ fase1/fase1_index.html: 12 KB
# ✅ fase2/fase2_index.html: 13 KB
# ✅ fase3/fase3_index.html: 13 KB
# ✅ fase1/m00_ejecucion.html: 12 KB
# ✅ fase2/m00_ejecucion.html: 11 KB
# ✅ fase3/m00_ejecucion.html: 12 KB
