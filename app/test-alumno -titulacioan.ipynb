# %%
import pandas as pd
ROOT = r"C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI"
df = pd.read_parquet(ROOT + r"\data\06_evaluacion\meta_test.parquet")
print(f"Total registros: {len(df):,}")
print(f"\nAlumnos por titulación (ordenado):")
print(df['titulacion'].value_counts().to_string())
# Out:
# Total registros: 6,725
#
# Alumnos por titulación (ordenado):
# titulacion
# Grado en Administración de Empresas                                   451
# Grado en Maestro en Educación Primaria                                446
# Grado en Derecho                                                      390
# Grado en Psicología                                                   366
# Grado en Finanzas y Contabilidad                                      360
# Grado en Maestro en Educación Infantil                                306
# Grado en Ingeniería en Diseño Industrial y Desarrollo de Productos    265
# Grado en Publicidad y Relaciones Públicas                             256
# Grado en Ingeniería Informática                                       247
# Grado en Comunicación Audiovisual                                     234
# Grado en Periodismo                                                   228
# Grado en Traducción e Interpretación                                  222
# ...
