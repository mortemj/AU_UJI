# %%
import pandas as pd
from pathlib import Path

ROOT = Path(r'C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI')
DIR  = ROOT / 'results' / 'fase6'

print('=== FAIRNESS ===')
df_fair = pd.read_parquet(DIR / 'fairness_metricas.parquet')
print(df_fair[['variable_sensible','dp_diff','dp_ratio','eq_opp_diff']].drop_duplicates().to_string())

print('\n=== ERRORES ===')
df_err = pd.read_parquet(DIR / 'errores_fpfn.parquet')
print(df_err['tipo'].value_counts())

print('\n=== CALIBRACIÓN ===')
df_cal = pd.read_parquet(DIR / 'calibracion_metricas.parquet')
print(df_cal.to_string())

print('\n=== STRESS ===')
df_str = pd.read_parquet(DIR / 'stress_resultados.parquet')
print(df_str.to_string())
# Out:
# === FAIRNESS ===
#    variable_sensible  dp_diff  dp_ratio  eq_opp_diff
# 0               sexo   0.1663    0.5947       0.0538
# 2               rama   0.2560    0.4039       0.0969
# 7         via_acceso   0.7500    0.0000       1.0000
# 20         tuvo_beca   0.2810    0.4618       0.1518
#
# === ERRORES ===
# tipo
# TN    4207
# TP    1592
# FP     551
# FN     375
# Name: count, dtype: int64
#
# === CALIBRACIÓN ===
#       metodo     brier
# 0   Original  0.099975
# 1  Isotónico  0.092270
# 2      Platt  0.094051
#
# === STRESS ===
#     nivel       auc        f1      test   pct  n_features                                                                                 features
# 0    0.05  0.922610  0.774068     ruido   NaN         NaN                                                                                     None
# 1    0.10  0.919889  0.768027     ruido   NaN         NaN                                                                                     None
# ...
