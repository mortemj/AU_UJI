# %%
import pandas as pd
meta = pd.read_parquet(r"C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\06_evaluacion\meta_test.parquet")
tits = sorted(meta["titulacion"].dropna().unique().tolist())
for t in tits:
    print(t)
# Out:
# Doble Grado en Administración y Dirección de Empresas y Derecho,
# Grado en Administración de Empresas
# Grado en Arquitectura Técnica
# Grado en Arquitectura Técnica (Plan 2020)
# Grado en Comunicación Audiovisual
# Grado en Criminologia y Seguridad
# Grado en Criminologia y Seguridad  (Plan 2020)
# Grado en Derecho
# Grado en Diseño y Desarrollo de Videojuegos
# Grado en Economía
# Grado en Enfermería
# Grado en Estudios Ingleses
# Grado en Finanzas y Contabilidad
# Grado en Gestión y Administración Pública
# Grado en Historia y Patrimonio
# Grado en Historia y Patrimonio (Plan 2015)
# Grado en Humanidades: Estudios Interculturales
# Grado en Ingeniería Agroalimentaria y del Medio Rural
# Grado en Ingeniería Agroalimentaria y del Medio Rural (Plan 2018)
# Grado en Ingeniería Eléctrica
# Grado en Ingeniería Informática
# Grado en Ingeniería Mecanica
# Grado en Ingeniería Química
# Grado en Ingeniería de la Edificación
# ...

# %%
import pandas as pd
meta = pd.read_parquet(r"C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\06_evaluacion\meta_test.parquet")
planes = meta[meta["titulacion"].str.contains(r"\(Plan", na=False)]
print(planes.groupby("titulacion")["per_id_ficticio"].count())
# Out:
# titulacion
# Grado en Arquitectura Técnica (Plan 2020)                             8
# Grado en Criminologia y Seguridad  (Plan 2020)                       16
# Grado en Historia y Patrimonio (Plan 2015)                           54
# Grado en Ingeniería Agroalimentaria y del Medio Rural (Plan 2018)    17
# Grado en Maestro en Educación Infantil (Plan 2018)                   94
# Grado en Maestro en Educación Primaria (Plan 2018)                   92
# Grado en Medicina (Plan 2017)                                        66
# Name: per_id_ficticio, dtype: int64
