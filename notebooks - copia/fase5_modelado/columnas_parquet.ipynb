# %%
import pandas as pd
from pathlib import Path

ruta = Path(r'C:\Users\mjmor\OneDrive - Universitat Jaume I\2.- AU_UJI\data\05_modelado\results')
for f in sorted(ruta.glob('*.parquet')):
    df = pd.read_parquet(f)
    print(f"\n{f.name}: {df.shape}")
    print(f"  cols: {list(df.columns)}")
    print(f"  {df[['modelo','estrategia']].head(3).to_string()}")
# Out:
# results_arboles.parquet: (9, 19)
#   cols: ['modelo', 'estrategia', 'familia', 'f1_mean', 'f1_std', 'auc_mean', 'auc_std', 'precision_mean', 'recall_mean', 'accuracy_mean', 'tiempo_s', 'memoria_mb', 'f1_test', 'auc_test', 'precision_test', 'recall_test', 'accuracy_test', 'kappa_test', 'logloss_test']
#            modelo estrategia
# 0  RandomForest       none
# 1  RandomForest   balanced
# 2  RandomForest      smote
#
# results_boosting.parquet: (12, 19)
#   cols: ['modelo', 'estrategia', 'familia', 'f1_mean', 'f1_std', 'auc_mean', 'auc_std', 'precision_mean', 'recall_mean', 'accuracy_mean', 'tiempo_s', 'memoria_mb', 'f1_test', 'auc_test', 'precision_test', 'recall_test', 'accuracy_test', 'kappa_test', 'logloss_test']
#        modelo estrategia
# 0   XGBoost       none
# 1  LightGBM       none
# 2   XGBoost   balanced
#
# results_boosting_prueba.parquet: (12, 19)
# ...
